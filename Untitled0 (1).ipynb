# %%
### gpu info ###
import pynvml

pynvml.nvmlInit()
handle = pynvml.nvmlDeviceGetHandleByIndex(0)
device_name = pynvml.nvmlDeviceGetName(handle)

if (device_name != b'Tesla T4') and (device_name != b'Tesla P4') and (device_name != b'Tesla P100-PCIE-16GB'):
  raise Exception("""
                     Unfortunately this instance does not have a T4, P4 or P100 GPU.\n
                     Please make sure you've configured Colab to request a GPU instance type.\n
                     Sometimes Colab allocates a Tesla K80 instead of a T4, P4 or P100. Resetting the instance.If you get a K80 GPU, try Runtime -> Reset all runtimes...""")
else:
  print('Woo! You got the right kind of GPU!')

! nvidia-smi
# Out:
# Woo! You got the right kind of GPU!
# Wed Mar  9 18:09:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
### add user ###
# !adduser rstudio
# Out:
# Adding user `rstudio' ...
# Adding new group `rstudio' (1000) ...
# Adding new user `rstudio' (1000) with group `rstudio' ...
# Creating home directory `/home/rstudio' ...
# Copying files from `/etc/skel' ...
# Enter new UNIX password:
# Retype new UNIX password:
# passwd: password updated successfully
# Changing the user information for rstudio
# Enter the new value, or press ENTER for the default
# 	Full Name []: oo
# 	Room Number []:
# 	Work Phone []:
# 	Home Phone []:
# 	Other []:
# Is the information correct? [Y/n] y

# %%
### geospatial softwares ###
# !apt-get update
# !apt-get install --yes git ssh python3-venv
# !apt-get install r-base r-base-dev gdal-bin python-gdal python3-gdal libgdal-dev libproj-dev proj-data proj-bin libgeos-dev libudunits2-dev libv8-dev libprotobuf-dev libxml2 libjq-dev
# !apt-get install qgis saga
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [829 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,067 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,628 kB]
# Get:19 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,478 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,256 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [863 kB]
# Fetched 11.4 MB in 3s (3,501 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.17.1-1ubuntu0.9).
# The following additional packages will be installed:
#   ncurses-term openssh-server openssh-sftp-server python-pip-whl
#   python3-certifi python3-chardet python3-idna python3-pkg-resources
#   python3-requests python3-six python3-urllib3 python3.6-venv ssh-import-id
# Suggested packages:
#   molly-guard monkeysphere rssh ssh-askpass ufw python3-setuptools
#   python3-cryptography python3-openssl python3-socks
# The following NEW packages will be installed:
#   ncurses-term openssh-server openssh-sftp-server python-pip-whl
#   python3-certifi python3-chardet python3-idna python3-pkg-resources
#   python3-requests python3-six python3-urllib3 python3-venv python3.6-venv ssh
#   ssh-import-id
# 0 upgraded, 15 newly installed, 0 to remove and 40 not upgraded.
# Need to get 2,813 kB of archives.
# After this operation, 9,618 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssh-sftp-server amd64 1:7.6p1-4ubuntu0.6 [45.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openssh-server amd64 1:7.6p1-4ubuntu0.6 [332 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ssh all 1:7.6p1-4ubuntu0.6 [5,196 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ncurses-term all 6.1-1ubuntu1.18.04 [248 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-pip-whl all 9.0.1-2.3~ubuntu1.18.04.5 [1,653 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-certifi all 2018.1.18-2 [144 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-chardet all 3.0.4-1 [80.3 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-idna all 2.6-1 [32.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-six all 1.11.0-2 [11.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-urllib3 all 1.22-1ubuntu0.18.04.2 [86.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-requests all 2.18.4-2ubuntu0.1 [58.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3.6-venv amd64 3.6.9-1~18.04ubuntu1.6 [6,184 B]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-venv amd64 3.6.7-1~18.04 [1,208 B]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ssh-import-id all 5.7-0ubuntu1.1 [10.9 kB]
# Fetched 2,813 kB in 1s (2,590 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package openssh-sftp-server.
# (Reading database ... 155332 files and directories currently installed.)
# Preparing to unpack .../00-openssh-sftp-server_1%3a7.6p1-4ubuntu0.6_amd64.deb ...
# Unpacking openssh-sftp-server (1:7.6p1-4ubuntu0.6) ...
# Selecting previously unselected package openssh-server.
# Preparing to unpack .../01-openssh-server_1%3a7.6p1-4ubuntu0.6_amd64.deb ...
# Unpacking openssh-server (1:7.6p1-4ubuntu0.6) ...
# Selecting previously unselected package ssh.
# Preparing to unpack .../02-ssh_1%3a7.6p1-4ubuntu0.6_all.deb ...
# Unpacking ssh (1:7.6p1-4ubuntu0.6) ...
# Selecting previously unselected package ncurses-term.
# Preparing to unpack .../03-ncurses-term_6.1-1ubuntu1.18.04_all.deb ...
# Unpacking ncurses-term (6.1-1ubuntu1.18.04) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../04-python-pip-whl_9.0.1-2.3~ubuntu1.18.04.5_all.deb ...
# Unpacking python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Selecting previously unselected package python3-certifi.
# Preparing to unpack .../05-python3-certifi_2018.1.18-2_all.deb ...
# Unpacking python3-certifi (2018.1.18-2) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../06-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../07-python3-chardet_3.0.4-1_all.deb ...
# Unpacking python3-chardet (3.0.4-1) ...
# Selecting previously unselected package python3-idna.
# Preparing to unpack .../08-python3-idna_2.6-1_all.deb ...
# Unpacking python3-idna (2.6-1) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../09-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-urllib3.
# Preparing to unpack .../10-python3-urllib3_1.22-1ubuntu0.18.04.2_all.deb ...
# Unpacking python3-urllib3 (1.22-1ubuntu0.18.04.2) ...
# Selecting previously unselected package python3-requests.
# Preparing to unpack .../11-python3-requests_2.18.4-2ubuntu0.1_all.deb ...
# Unpacking python3-requests (2.18.4-2ubuntu0.1) ...
# Selecting previously unselected package python3.6-venv.
# Preparing to unpack .../12-python3.6-venv_3.6.9-1~18.04ubuntu1.6_amd64.deb ...
# Unpacking python3.6-venv (3.6.9-1~18.04ubuntu1.6) ...
# Selecting previously unselected package python3-venv.
# Preparing to unpack .../13-python3-venv_3.6.7-1~18.04_amd64.deb ...
# Unpacking python3-venv (3.6.7-1~18.04) ...
# Selecting previously unselected package ssh-import-id.
# Preparing to unpack .../14-ssh-import-id_5.7-0ubuntu1.1_all.deb ...
# Unpacking ssh-import-id (5.7-0ubuntu1.1) ...
# Setting up python-pip-whl (9.0.1-2.3~ubuntu1.18.04.5) ...
# Setting up ncurses-term (6.1-1ubuntu1.18.04) ...
# Setting up python3-idna (2.6-1) ...
# Setting up python3-six (1.11.0-2) ...
# Setting up python3.6-venv (3.6.9-1~18.04ubuntu1.6) ...
# Setting up python3-certifi (2018.1.18-2) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up openssh-sftp-server (1:7.6p1-4ubuntu0.6) ...
# Setting up python3-chardet (3.0.4-1) ...
# Setting up python3-urllib3 (1.22-1ubuntu0.18.04.2) ...
# Setting up python3-venv (3.6.7-1~18.04) ...
# Setting up openssh-server (1:7.6p1-4ubuntu0.6) ...
#
# Creating config file /etc/ssh/sshd_config with new version
# Creating SSH2 RSA key; this may take some time ...
# 2048 SHA256:/6n0XF6M8SM+E4bN8b1MS40e/EtDcfPRp2Ha+FgpOgY root@7e2a64dad834 (RSA)
# Creating SSH2 ECDSA key; this may take some time ...
# 256 SHA256:vDX9DMsEXA4Yb1TtjodqrX9pDNmmdUo4rDpsD0b4ym8 root@7e2a64dad834 (ECDSA)
# Creating SSH2 ED25519 key; this may take some time ...
# 256 SHA256:xONevIuQXN2EBdOPypee4x00hp2Vz6FEr2zTbU657RM root@7e2a64dad834 (ED25519)
# Created symlink /etc/systemd/system/sshd.service → /lib/systemd/system/ssh.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/ssh.service → /lib/systemd/system/ssh.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up python3-requests (2.18.4-2ubuntu0.1) ...
# Setting up ssh-import-id (5.7-0ubuntu1.1) ...
# Setting up ssh (1:7.6p1-4ubuntu0.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for systemd (237-3ubuntu10.53) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gdal-bin is already the newest version (2.2.3+dfsg-2).
# libgdal-dev is already the newest version (2.2.3+dfsg-2).
# libgeos-dev is already the newest version (3.6.2-1build2).
# libgeos-dev set to manually installed.
# libproj-dev is already the newest version (4.9.3-2).
# libproj-dev set to manually installed.
# proj-data is already the newest version (4.9.3-2).
# proj-data set to manually installed.
# python-gdal is already the newest version (2.2.3+dfsg-2).
# libxml2 is already the newest version (2.9.4+dfsg1-6.1ubuntu1.4).
# libxml2 set to manually installed.
# r-base-dev is already the newest version (4.1.2-1.1804.0).
# r-base is already the newest version (4.1.2-1.1804.0).
# The following additional packages will be installed:
#   libjq1 libonig4 libprotobuf-lite10 libudunits2-0 libudunits2-data
#   libv8-3.14.5 python3-numpy
# Suggested packages:
#   python-numpy-doc python3-nose python3-numpy-dbg
# The following NEW packages will be installed:
#   libjq-dev libjq1 libonig4 libprotobuf-dev libprotobuf-lite10 libudunits2-0
#   libudunits2-data libudunits2-dev libv8-3.14.5 libv8-dev proj-bin
#   python3-gdal python3-numpy
# 0 upgraded, 13 newly installed, 0 to remove and 40 not upgraded.
# Need to get 5,325 kB of archives.
# After this operation, 28.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libonig4 amd64 6.7.0-1 [119 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjq1 amd64 1.5+dfsg-2 [111 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjq-dev amd64 1.5+dfsg-2 [10.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libudunits2-data all 2.2.26-1 [18.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libudunits2-0 amd64 2.2.26-1 [54.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libudunits2-dev amd64 2.2.26-1 [362 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libv8-3.14.5 amd64 3.14.5.8-11ubuntu1 [1,214 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-numpy amd64 1:1.13.3-2ubuntu1 [1,943 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-gdal amd64 2.2.3+dfsg-2 [346 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libv8-dev amd64 3.14.5.8-11ubuntu1 [57.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 proj-bin amd64 4.9.3-2 [32.3 kB]
# Fetched 5,325 kB in 1s (4,633 kB/s)
# Selecting previously unselected package libonig4:amd64.
# (Reading database ... 158387 files and directories currently installed.)
# Preparing to unpack .../00-libonig4_6.7.0-1_amd64.deb ...
# Unpacking libonig4:amd64 (6.7.0-1) ...
# Selecting previously unselected package libjq1:amd64.
# Preparing to unpack .../01-libjq1_1.5+dfsg-2_amd64.deb ...
# Unpacking libjq1:amd64 (1.5+dfsg-2) ...
# Selecting previously unselected package libjq-dev:amd64.
# Preparing to unpack .../02-libjq-dev_1.5+dfsg-2_amd64.deb ...
# Unpacking libjq-dev:amd64 (1.5+dfsg-2) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../03-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libudunits2-data.
# Preparing to unpack .../04-libudunits2-data_2.2.26-1_all.deb ...
# Unpacking libudunits2-data (2.2.26-1) ...
# Selecting previously unselected package libudunits2-0:amd64.
# Preparing to unpack .../05-libudunits2-0_2.2.26-1_amd64.deb ...
# Unpacking libudunits2-0:amd64 (2.2.26-1) ...
# Selecting previously unselected package libudunits2-dev.
# Preparing to unpack .../06-libudunits2-dev_2.2.26-1_amd64.deb ...
# Unpacking libudunits2-dev (2.2.26-1) ...
# Selecting previously unselected package libv8-3.14.5.
# Preparing to unpack .../07-libv8-3.14.5_3.14.5.8-11ubuntu1_amd64.deb ...
# Unpacking libv8-3.14.5 (3.14.5.8-11ubuntu1) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../08-python3-numpy_1%3a1.13.3-2ubuntu1_amd64.deb ...
# Unpacking python3-numpy (1:1.13.3-2ubuntu1) ...
# Selecting previously unselected package python3-gdal.
# Preparing to unpack .../09-python3-gdal_2.2.3+dfsg-2_amd64.deb ...
# Unpacking python3-gdal (2.2.3+dfsg-2) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../10-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libv8-dev.
# Preparing to unpack .../11-libv8-dev_3.14.5.8-11ubuntu1_amd64.deb ...
# Unpacking libv8-dev (3.14.5.8-11ubuntu1) ...
# Selecting previously unselected package proj-bin.
# Preparing to unpack .../12-proj-bin_4.9.3-2_amd64.deb ...
# Unpacking proj-bin (4.9.3-2) ...
# Setting up python3-numpy (1:1.13.3-2ubuntu1) ...
# Setting up libonig4:amd64 (6.7.0-1) ...
# Setting up libv8-3.14.5 (3.14.5.8-11ubuntu1) ...
# Setting up libudunits2-data (2.2.26-1) ...
# Setting up python3-gdal (2.2.3+dfsg-2) ...
# Setting up libjq1:amd64 (1.5+dfsg-2) ...
# Setting up proj-bin (4.9.3-2) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libv8-dev (3.14.5.8-11ubuntu1) ...
# Setting up libudunits2-0:amd64 (2.2.26-1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libjq-dev:amd64 (1.5+dfsg-2) ...
# Setting up libudunits2-dev (2.2.26-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-lyx grass-core grass-doc javascript-common libaudio2 libdxflib3
#   libfcgi-bin libfcgi0ldbl libgail-common libgail18 libgsl23 libgslcblas0
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libhpdf-2.3.0 libjs-jquery
#   libjs-jquery-ui libjs-leaflet libjs-sphinxdoc libjs-underscore liblas-c3
#   liblas3 liblwgeom-2.4-0 liblwgeom-dev libmng2 libnotify4 libqca2
#   libqca2-plugins libqgis-analysis2.18.17 libqgis-app2.18.17
#   libqgis-core2.18.17 libqgis-customwidgets libqgis-gui2.18.17
#   libqgis-networkanalysis2.18.17 libqgis-server2.18.17 libqgisgrass7-2.18.17
#   libqgispython2.18.17 libqjson0 libqscintilla2-qt4-13 libqscintilla2-qt4-l10n
#   libqt4-dbus libqt4-declarative libqt4-designer libqt4-dev libqt4-dev-bin
#   libqt4-help libqt4-network libqt4-opengl libqt4-opengl-dev libqt4-qt3support
#   libqt4-script libqt4-scripttools libqt4-sql libqt4-sql-mysql
#   libqt4-sql-sqlite libqt4-svg libqt4-test libqt4-xml libqt4-xmlpatterns
#   libqtassistantclient4 libqtcore4 libqtdbus4 libqtgui4 libqwt6abi1
#   libsaga-api-2.3.1 libsaga-gdi-2.3.1 libspatialindex4v5 libsvm3
#   libvigraimpex6 libwxbase3.0-0v5 libwxgtk3.0-0v5 notification-daemon
#   python-asn1crypto python-backports.functools-lru-cache python-bs4
#   python-certifi python-cffi-backend python-chardet python-configparser
#   python-cryptography python-cycler python-dateutil python-egenix-mxdatetime
#   python-egenix-mxtools python-enum34 python-future python-html5lib
#   python-httplib2 python-idna python-ipaddress python-jinja2 python-lxml
#   python-markupsafe python-matplotlib python-matplotlib-data python-olefile
#   python-openssl python-owslib python-pil python-pkg-resources python-psycopg2
#   python-pygments python-pyparsing python-pyproj python-pyspatialite
#   python-qgis python-qgis-common python-qscintilla2 python-qt4 python-qt4-sql
#   python-requests python-shapely python-sip python-six python-subprocess32
#   python-tz python-urllib3 python-webencodings python-yaml qdbus qgis-common
#   qgis-plugin-grass qgis-plugin-grass-common qgis-provider-grass
#   qgis-providers qgis-providers-common qt-at-spi qt4-designer
#   qt4-linguist-tools qt4-qmake qtcore4-l10n saga-common ttf-bitstream-vera
# Suggested packages:
#   grass-dev grass-gui e00compr avce00 gnuplot gpsbabel gpstrans netpbm
#   python-rpy2 python-termcolor grass grass-dev-doc apache2 | lighttpd | httpd
#   nas gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info | gsl-ref-html gvfs
#   libjs-jquery-ui-docs libgeotiff-epsg libqscintilla2-doc
#   libqt4-declarative-folderlistmodel libqt4-declarative-gestures
#   libqt4-declarative-particles libqt4-declarative-shaders qt4-qmlviewer
#   firebird-dev libsqlite0-dev qt4-dev-tools qt4-doc libicu55 qt4-qtconfig
#   python-cryptography-doc python-cryptography-vectors python-cycler-doc
#   python-egenix-mxdatetime-dbg python-egenix-mxdatetime-doc
#   python-egenix-mxtools-dbg python-egenix-mxtools-doc python-enum34-doc
#   python-future-doc python-genshi python-jinja2-doc python-lxml-dbg
#   python-lxml-doc dvipng gir1.2-gtk-3.0 ghostscript inkscape ipython
#   python-cairocffi python-configobj python-excelerator python-gobject
#   python-matplotlib-doc python-nose python-scipy python-tornado python-traits
#   python-wxgtk3.0 texlive-extra-utils texlive-latex-extra ttf-staypuft
#   python-openssl-doc python-openssl-dbg owslib-doc python-pil-doc
#   python-pil-dbg python-setuptools python-psycopg2-doc python-pyparsing-doc
#   python-qt4-dbg python-socks python-shapely-doc python-ntlm
# The following NEW packages will be installed:
#   fonts-lyx grass-core grass-doc javascript-common libaudio2 libdxflib3
#   libfcgi-bin libfcgi0ldbl libgail-common libgail18 libgsl23 libgslcblas0
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libhpdf-2.3.0 libjs-jquery
#   libjs-jquery-ui libjs-leaflet libjs-sphinxdoc libjs-underscore liblas-c3
#   liblas3 liblwgeom-2.4-0 liblwgeom-dev libmng2 libnotify4 libqca2
#   libqca2-plugins libqgis-analysis2.18.17 libqgis-app2.18.17
#   libqgis-core2.18.17 libqgis-customwidgets libqgis-gui2.18.17
#   libqgis-networkanalysis2.18.17 libqgis-server2.18.17 libqgisgrass7-2.18.17
#   libqgispython2.18.17 libqjson0 libqscintilla2-qt4-13 libqscintilla2-qt4-l10n
#   libqt4-dbus libqt4-declarative libqt4-designer libqt4-dev libqt4-dev-bin
#   libqt4-help libqt4-network libqt4-opengl libqt4-opengl-dev libqt4-qt3support
#   libqt4-script libqt4-scripttools libqt4-sql libqt4-sql-mysql
#   libqt4-sql-sqlite libqt4-svg libqt4-test libqt4-xml libqt4-xmlpatterns
#   libqtassistantclient4 libqtcore4 libqtdbus4 libqtgui4 libqwt6abi1
#   libsaga-api-2.3.1 libsaga-gdi-2.3.1 libspatialindex4v5 libsvm3
#   libvigraimpex6 libwxbase3.0-0v5 libwxgtk3.0-0v5 notification-daemon
#   python-asn1crypto python-backports.functools-lru-cache python-bs4
#   python-certifi python-cffi-backend python-chardet python-configparser
#   python-cryptography python-cycler python-dateutil python-egenix-mxdatetime
#   python-egenix-mxtools python-enum34 python-future python-html5lib
#   python-httplib2 python-idna python-ipaddress python-jinja2 python-lxml
#   python-markupsafe python-matplotlib python-matplotlib-data python-olefile
#   python-openssl python-owslib python-pil python-pkg-resources python-psycopg2
#   python-pygments python-pyparsing python-pyproj python-pyspatialite
#   python-qgis python-qgis-common python-qscintilla2 python-qt4 python-qt4-sql
#   python-requests python-shapely python-sip python-six python-subprocess32
#   python-tz python-urllib3 python-webencodings python-yaml qdbus qgis
#   qgis-common qgis-plugin-grass qgis-plugin-grass-common qgis-provider-grass
#   qgis-providers qgis-providers-common qt-at-spi qt4-designer
#   qt4-linguist-tools qt4-qmake qtcore4-l10n saga saga-common
#   ttf-bitstream-vera
# 0 upgraded, 136 newly installed, 0 to remove and 40 not upgraded.
# Need to get 129 MB of archives.
# After this operation, 509 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmng2 amd64 2.0.2-0ubuntu3 [169 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qtcore4-l10n all 4:4.8.7+dfsg-7ubuntu1 [617 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtcore4 amd64 4:4.8.7+dfsg-7ubuntu1 [1,552 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqjson0 amd64 0.8.1-3 [63.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis-providers-common all 2.18.17+dfsg-1 [791 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqca2 amd64 2.1.3-2ubuntu2 [300 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqca2-plugins amd64 2.1.3-2ubuntu2 [184 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-sql amd64 4:4.8.7+dfsg-7ubuntu1 [98.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-sql-sqlite amd64 4:4.8.7+dfsg-7ubuntu1 [23.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-xml amd64 4:4.8.7+dfsg-7ubuntu1 [96.1 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtdbus4 amd64 4:4.8.7+dfsg-7ubuntu1 [186 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-network amd64 4:4.8.7+dfsg-7ubuntu1 [562 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaudio2 amd64 1.9.4-6 [50.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-script amd64 4:4.8.7+dfsg-7ubuntu1 [815 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-xmlpatterns amd64 4:4.8.7+dfsg-7ubuntu1 [1,091 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-declarative amd64 4:4.8.7+dfsg-7ubuntu1 [1,089 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtgui4 amd64 4:4.8.7+dfsg-7ubuntu1 [4,115 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-svg amd64 4:4.8.7+dfsg-7ubuntu1 [138 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialindex4v5 amd64 1.8.5-5 [219 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-core2.18.17 amd64 2.18.17+dfsg-1 [3,017 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqscintilla2-qt4-l10n all 2.10.2+dfsg-4 [39.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqscintilla2-qt4-13 amd64 2.10.2+dfsg-4 [1,018 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-opengl amd64 4:4.8.7+dfsg-7ubuntu1 [301 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqwt6abi1 amd64 6.1.3-1 [395 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-gui2.18.17 amd64 2.18.17+dfsg-1 [2,051 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis-providers amd64 2.18.17+dfsg-1 [1,363 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 fonts-lyx all 2.2.4-0ubuntu0.18.04.1 [155 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 grass-doc all 7.4.0-1 [31.2 MB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblas3 amd64 1.8.1-6build1 [270 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblas-c3 amd64 1.8.1-6build1 [65.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/universe amd64 grass-core amd64 7.4.0-1 [5,410 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdxflib3 amd64 3.17.0-2 [52.0 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfcgi0ldbl amd64 2.4.0-10 [154 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfcgi-bin amd64 2.4.0-10 [10.6 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgslcblas0 amd64 2.4+dfsg-6 [79.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsl23 amd64 2.4+dfsg-6 [823 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhpdf-2.3.0 amd64 2.3.0+dfsg-1 [336 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjs-underscore all 1.8.3~dfsg-1ubuntu0.1 [60.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-sphinxdoc all 1.6.7-1ubuntu1 [85.6 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblwgeom-2.4-0 amd64 2.4.3+dfsg-4 [212 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblwgeom-dev amd64 2.4.3+dfsg-4 [249 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnotify4 amd64 0.7.7-3 [17.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-analysis2.18.17 amd64 2.18.17+dfsg-1 [187 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-app2.18.17 amd64 2.18.17+dfsg-1 [2,331 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-designer amd64 4:4.8.7+dfsg-7ubuntu1 [3,629 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qt4-designer amd64 4:4.8.7+dfsg-7ubuntu1 [351 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-customwidgets amd64 2.18.17+dfsg-1 [4,322 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-networkanalysis2.18.17 amd64 2.18.17+dfsg-1 [52.7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgis-server2.18.17 amd64 2.18.17+dfsg-1 [401 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgisgrass7-2.18.17 amd64 2.18.17+dfsg-1 [215 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqgispython2.18.17 amd64 2.18.17+dfsg-1 [46.9 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qdbus amd64 4:4.8.7+dfsg-7ubuntu1 [30.0 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-dbus amd64 4:4.8.7+dfsg-7ubuntu1 [6,440 B]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-qt3support amd64 4:4.8.7+dfsg-7ubuntu1 [1,049 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-dev-bin amd64 4:4.8.7+dfsg-7ubuntu1 [1,706 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-help amd64 4:4.8.7+dfsg-7ubuntu1 [207 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-scripttools amd64 4:4.8.7+dfsg-7ubuntu1 [225 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-test amd64 4:4.8.7+dfsg-7ubuntu1 [61.2 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qt4-linguist-tools amd64 4:4.8.7+dfsg-7ubuntu1 [879 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qt4-qmake amd64 4:4.8.7+dfsg-7ubuntu1 [1,366 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-dev amd64 4:4.8.7+dfsg-7ubuntu1 [853 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-opengl-dev amd64 4:4.8.7+dfsg-7ubuntu1 [22.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqt4-sql-mysql amd64 4:4.8.7+dfsg-7ubuntu1 [30.5 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqtassistantclient4 amd64 4.6.3-7build1 [12.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwxbase3.0-0v5 amd64 3.0.4+dfsg-3 [954 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsaga-api-2.3.1 amd64 2.3.1+dfsg-3build7 [483 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwxgtk3.0-0v5 amd64 3.0.4+dfsg-3 [4,182 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsaga-gdi-2.3.1 amd64 2.3.1+dfsg-3build7 [64.2 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsvm3 amd64 3.21+ds-1.1 [40.0 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvigraimpex6 amd64 1.10.0+git20160211.167be93+dfsg-5ubuntu1 [169 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/main amd64 notification-daemon amd64 3.20.0-3 [36.9 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-asn1crypto all 0.24.0-1 [72.7 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-backports.functools-lru-cache all 1.4-2 [5,960 B]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-certifi all 2018.1.18-2 [144 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-cffi-backend amd64 1.11.5-1 [63.4 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pkg-resources all 39.0.1-2 [128 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-chardet all 3.0.4-1 [80.3 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-configparser all 3.5.0-1 [59.6 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-enum34 all 1.1.6-2 [34.8 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-idna all 2.6-1 [32.4 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-ipaddress all 1.0.17-1 [18.2 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-six all 1.11.0-2 [11.3 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-cryptography amd64 2.1.4-1ubuntu1.4 [276 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-cycler all 0.10.0-1 [7,520 B]
# Get:94 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-dateutil all 2.6.1-1 [60.6 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-egenix-mxtools amd64 3.2.9-1 [75.3 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-egenix-mxdatetime amd64 3.2.9-1 [68.3 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-future all 0.15.2-4ubuntu2 [335 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-webencodings all 0.5-2 [10.3 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-html5lib all 0.999999999-1 [83.6 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-httplib2 all 0.9.2+dfsg-1ubuntu0.3 [34.9 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-markupsafe amd64 1.0-1build1 [13.0 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-jinja2 all 2.10-1ubuntu0.18.04.1 [94.8 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-lxml amd64 4.2.1-1ubuntu0.6 [898 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-matplotlib-data all 2.1.1-2ubuntu3 [3,774 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-pyparsing all 2.2.0+dfsg1-2 [52.1 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-tz all 2018.3-2 [31.6 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-subprocess32 amd64 3.2.7-3 [27.2 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-matplotlib amd64 2.1.1-2ubuntu3 [3,901 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-olefile all 0.45.1-1 [33.2 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-openssl all 17.5.0-1ubuntu1 [41.3 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pyproj amd64 1.9.5.1-3build1 [40.0 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-urllib3 all 1.22-1ubuntu0.18.04.2 [86.0 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-requests all 2.18.4-2ubuntu0.1 [58.5 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-owslib all 0.16.0-1 [96.0 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pil amd64 5.1.0-1ubuntu0.7 [303 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-psycopg2 amd64 2.7.4-1 [155 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-pygments all 2.2.0+dfsg-1ubuntu0.2 [576 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python-sip amd64 4.19.7+dfsg-1ubuntu0.1 [75.2 kB]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-qt4 amd64 4.12.1+dfsg-2 [2,194 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-qt4-sql amd64 4.12.1+dfsg-2 [78.3 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-shapely amd64 1.6.4-1 [221 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-yaml amd64 3.12-1build2 [115 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-qgis-common all 2.18.17+dfsg-1 [2,397 kB]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pyspatialite amd64 3.0.1-12 [29.8 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-qscintilla2 amd64 2.10.2+dfsg-4 [215 kB]
# Get:127 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-qgis amd64 2.18.17+dfsg-1 [3,698 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-leaflet all 0.7.7+20160312-1 [91.0 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis-common all 2.18.17+dfsg-1 [11.1 MB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis amd64 2.18.17+dfsg-1 [5,263 kB]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis-plugin-grass-common all 2.18.17+dfsg-1 [460 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis-provider-grass amd64 2.18.17+dfsg-1 [86.7 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qgis-plugin-grass amd64 2.18.17+dfsg-1 [588 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic/universe amd64 qt-at-spi amd64 0.4.0-8 [58.6 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/universe amd64 saga-common all 2.3.1+dfsg-3build7 [116 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/universe amd64 saga amd64 2.3.1+dfsg-3build7 [4,636 kB]
# Fetched 129 MB in 7s (19.3 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libmng2:amd64.
# (Reading database ... 159003 files and directories currently installed.)
# Preparing to unpack .../000-libmng2_2.0.2-0ubuntu3_amd64.deb ...
# Unpacking libmng2:amd64 (2.0.2-0ubuntu3) ...
# Selecting previously unselected package qtcore4-l10n.
# Preparing to unpack .../001-qtcore4-l10n_4%3a4.8.7+dfsg-7ubuntu1_all.deb ...
# Unpacking qtcore4-l10n (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqtcore4:amd64.
# Preparing to unpack .../002-libqtcore4_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqtcore4:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqjson0:amd64.
# Preparing to unpack .../003-libqjson0_0.8.1-3_amd64.deb ...
# Unpacking libqjson0:amd64 (0.8.1-3) ...
# Selecting previously unselected package qgis-providers-common.
# Preparing to unpack .../004-qgis-providers-common_2.18.17+dfsg-1_all.deb ...
# Unpacking qgis-providers-common (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqca2:amd64.
# Preparing to unpack .../005-libqca2_2.1.3-2ubuntu2_amd64.deb ...
# Unpacking libqca2:amd64 (2.1.3-2ubuntu2) ...
# Selecting previously unselected package libqca2-plugins:amd64.
# Preparing to unpack .../006-libqca2-plugins_2.1.3-2ubuntu2_amd64.deb ...
# Unpacking libqca2-plugins:amd64 (2.1.3-2ubuntu2) ...
# Selecting previously unselected package libqt4-sql:amd64.
# Preparing to unpack .../007-libqt4-sql_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-sql:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-sql-sqlite:amd64.
# Preparing to unpack .../008-libqt4-sql-sqlite_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-sql-sqlite:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-xml:amd64.
# Preparing to unpack .../009-libqt4-xml_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-xml:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqtdbus4:amd64.
# Preparing to unpack .../010-libqtdbus4_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqtdbus4:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-network:amd64.
# Preparing to unpack .../011-libqt4-network_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-network:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libaudio2:amd64.
# Preparing to unpack .../012-libaudio2_1.9.4-6_amd64.deb ...
# Unpacking libaudio2:amd64 (1.9.4-6) ...
# Selecting previously unselected package libqt4-script:amd64.
# Preparing to unpack .../013-libqt4-script_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-script:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-xmlpatterns:amd64.
# Preparing to unpack .../014-libqt4-xmlpatterns_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-xmlpatterns:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-declarative:amd64.
# Preparing to unpack .../015-libqt4-declarative_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-declarative:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqtgui4:amd64.
# Preparing to unpack .../016-libqtgui4_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqtgui4:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-svg:amd64.
# Preparing to unpack .../017-libqt4-svg_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-svg:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libspatialindex4v5:amd64.
# Preparing to unpack .../018-libspatialindex4v5_1.8.5-5_amd64.deb ...
# Unpacking libspatialindex4v5:amd64 (1.8.5-5) ...
# Selecting previously unselected package libqgis-core2.18.17.
# Preparing to unpack .../019-libqgis-core2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-core2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqscintilla2-qt4-l10n.
# Preparing to unpack .../020-libqscintilla2-qt4-l10n_2.10.2+dfsg-4_all.deb ...
# Unpacking libqscintilla2-qt4-l10n (2.10.2+dfsg-4) ...
# Selecting previously unselected package libqscintilla2-qt4-13.
# Preparing to unpack .../021-libqscintilla2-qt4-13_2.10.2+dfsg-4_amd64.deb ...
# Unpacking libqscintilla2-qt4-13 (2.10.2+dfsg-4) ...
# Selecting previously unselected package libqt4-opengl:amd64.
# Preparing to unpack .../022-libqt4-opengl_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-opengl:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqwt6abi1.
# Preparing to unpack .../023-libqwt6abi1_6.1.3-1_amd64.deb ...
# Unpacking libqwt6abi1 (6.1.3-1) ...
# Selecting previously unselected package libqgis-gui2.18.17.
# Preparing to unpack .../024-libqgis-gui2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-gui2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package qgis-providers.
# Preparing to unpack .../025-qgis-providers_2.18.17+dfsg-1_amd64.deb ...
# Unpacking qgis-providers (2.18.17+dfsg-1) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../026-fonts-lyx_2.2.4-0ubuntu0.18.04.1_all.deb ...
# Unpacking fonts-lyx (2.2.4-0ubuntu0.18.04.1) ...
# Selecting previously unselected package grass-doc.
# Preparing to unpack .../027-grass-doc_7.4.0-1_all.deb ...
# Unpacking grass-doc (7.4.0-1) ...
# Selecting previously unselected package liblas3.
# Preparing to unpack .../028-liblas3_1.8.1-6build1_amd64.deb ...
# Unpacking liblas3 (1.8.1-6build1) ...
# Selecting previously unselected package liblas-c3.
# Preparing to unpack .../029-liblas-c3_1.8.1-6build1_amd64.deb ...
# Unpacking liblas-c3 (1.8.1-6build1) ...
# Selecting previously unselected package grass-core.
# Preparing to unpack .../030-grass-core_7.4.0-1_amd64.deb ...
# Unpacking grass-core (7.4.0-1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../031-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libdxflib3:amd64.
# Preparing to unpack .../032-libdxflib3_3.17.0-2_amd64.deb ...
# Unpacking libdxflib3:amd64 (3.17.0-2) ...
# Selecting previously unselected package libfcgi0ldbl:amd64.
# Preparing to unpack .../033-libfcgi0ldbl_2.4.0-10_amd64.deb ...
# Unpacking libfcgi0ldbl:amd64 (2.4.0-10) ...
# Selecting previously unselected package libfcgi-bin.
# Preparing to unpack .../034-libfcgi-bin_2.4.0-10_amd64.deb ...
# Unpacking libfcgi-bin (2.4.0-10) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../035-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../036-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../037-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../038-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgslcblas0:amd64.
# Preparing to unpack .../039-libgslcblas0_2.4+dfsg-6_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgsl23:amd64.
# Preparing to unpack .../040-libgsl23_2.4+dfsg-6_amd64.deb ...
# Unpacking libgsl23:amd64 (2.4+dfsg-6) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../041-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libhpdf-2.3.0:amd64.
# Preparing to unpack .../042-libhpdf-2.3.0_2.3.0+dfsg-1_amd64.deb ...
# Unpacking libhpdf-2.3.0:amd64 (2.3.0+dfsg-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../043-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../044-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../045-libjs-underscore_1.8.3~dfsg-1ubuntu0.1_all.deb ...
# Unpacking libjs-underscore (1.8.3~dfsg-1ubuntu0.1) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../046-libjs-sphinxdoc_1.6.7-1ubuntu1_all.deb ...
# Unpacking libjs-sphinxdoc (1.6.7-1ubuntu1) ...
# Selecting previously unselected package liblwgeom-2.4-0.
# Preparing to unpack .../047-liblwgeom-2.4-0_2.4.3+dfsg-4_amd64.deb ...
# Unpacking liblwgeom-2.4-0 (2.4.3+dfsg-4) ...
# Selecting previously unselected package liblwgeom-dev.
# Preparing to unpack .../048-liblwgeom-dev_2.4.3+dfsg-4_amd64.deb ...
# Unpacking liblwgeom-dev (2.4.3+dfsg-4) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../049-libnotify4_0.7.7-3_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.7-3) ...
# Selecting previously unselected package libqgis-analysis2.18.17.
# Preparing to unpack .../050-libqgis-analysis2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-analysis2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqgis-app2.18.17.
# Preparing to unpack .../051-libqgis-app2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-app2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqt4-designer:amd64.
# Preparing to unpack .../052-libqt4-designer_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-designer:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package qt4-designer.
# Preparing to unpack .../053-qt4-designer_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking qt4-designer (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqgis-customwidgets.
# Preparing to unpack .../054-libqgis-customwidgets_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-customwidgets (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqgis-networkanalysis2.18.17.
# Preparing to unpack .../055-libqgis-networkanalysis2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-networkanalysis2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqgis-server2.18.17.
# Preparing to unpack .../056-libqgis-server2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgis-server2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqgisgrass7-2.18.17.
# Preparing to unpack .../057-libqgisgrass7-2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgisgrass7-2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package libqgispython2.18.17.
# Preparing to unpack .../058-libqgispython2.18.17_2.18.17+dfsg-1_amd64.deb ...
# Unpacking libqgispython2.18.17 (2.18.17+dfsg-1) ...
# Selecting previously unselected package qdbus.
# Preparing to unpack .../059-qdbus_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking qdbus (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-dbus:amd64.
# Preparing to unpack .../060-libqt4-dbus_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-dbus:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-qt3support:amd64.
# Preparing to unpack .../061-libqt4-qt3support_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-qt3support:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-dev-bin.
# Preparing to unpack .../062-libqt4-dev-bin_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-dev-bin (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-help:amd64.
# Preparing to unpack .../063-libqt4-help_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-help:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-scripttools:amd64.
# Preparing to unpack .../064-libqt4-scripttools_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-scripttools:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-test:amd64.
# Preparing to unpack .../065-libqt4-test_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-test:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package qt4-linguist-tools.
# Preparing to unpack .../066-qt4-linguist-tools_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking qt4-linguist-tools (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package qt4-qmake.
# Preparing to unpack .../067-qt4-qmake_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking qt4-qmake (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-dev.
# Preparing to unpack .../068-libqt4-dev_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-dev (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-opengl-dev.
# Preparing to unpack .../069-libqt4-opengl-dev_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-opengl-dev (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqt4-sql-mysql:amd64.
# Preparing to unpack .../070-libqt4-sql-mysql_4%3a4.8.7+dfsg-7ubuntu1_amd64.deb ...
# Unpacking libqt4-sql-mysql:amd64 (4:4.8.7+dfsg-7ubuntu1) ...
# Selecting previously unselected package libqtassistantclient4:amd64.
# Preparing to unpack .../071-libqtassistantclient4_4.6.3-7build1_amd64.deb ...
# Unpacking libqtassistantclient4:amd64 (4.6.3-7build1) ...
# Selecting previously unselected package libwxbase3.0-0v5:amd64.
# Preparing to unpack .../072-libwxbase3.0-0v5_3.0.4+dfsg-3_amd64.deb ...
# Unpacking libwxbase3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Selecting previously unselected package libsaga-api-2.3.1:amd64.
# Preparing to unpack .../073-libsaga-api-2.3.1_2.3.1+dfsg-3build7_amd64.deb ...
# Unpacking libsaga-api-2.3.1:amd64 (2.3.1+dfsg-3build7) ...
# Selecting previously unselected package libwxgtk3.0-0v5:amd64.
# Preparing to unpack .../074-libwxgtk3.0-0v5_3.0.4+dfsg-3_amd64.deb ...
# Unpacking libwxgtk3.0-0v5:amd64 (3.0.4+dfsg-3) ...
# Selecting previously unselected package libsaga-gdi-2.3.1:amd64.
# Preparing to unpack .../075-libsaga-gdi-2.3.1_2.3.1+dfsg-3build7_amd64.deb ...
# Unpacking libsaga-gdi-2.3.1:amd64 (2.3.1+dfsg-3build7) ...
# Selecting previously unselected package libsvm3.
# Preparing to unpack .../076-libsvm3_3.21+ds-1.1_amd64.deb ...
# Unpacking libsvm3 (3.21+ds-1.1) ...
# Selecting previously unselected package libvigraimpex6:amd64.
# Preparing to unpack .../077-libvigraimpex6_1.10.0+git20160211.167be93+dfsg-5ubuntu1_amd64.deb ...
# Unpacking libvigraimpex6:amd64 (1.10.0+git20160211.167be93+dfsg-5ubuntu1) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../078-notification-daemon_3.20.0-3_amd64.deb ...
# Unpacking notification-daemon (3.20.0-3) ...
# Selecting previously unselected package python-asn1crypto.
# Preparing to unpack .../079-python-asn1crypto_0.24.0-1_all.deb ...
# Unpacking python-asn1crypto (0.24.0-1) ...
# Selecting previously unselected package python-backports.functools-lru-cache.
# Preparing to unpack .../080-python-backports.functools-lru-cache_1.4-2_all.deb ...
# Unpacking python-backports.functools-lru-cache (1.4-2) ...
# Selecting previously unselected package python-bs4.
# Preparing to unpack .../081-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-certifi.
# Preparing to unpack .../082-python-certifi_2018.1.18-2_all.deb ...
# Unpacking python-certifi (2018.1.18-2) ...
# Selecting previously unselected package python-cffi-backend.
# Preparing to unpack .../083-python-cffi-backend_1.11.5-1_amd64.deb ...
# Unpacking python-cffi-backend (1.11.5-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../084-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../085-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-configparser.
# Preparing to unpack .../086-python-configparser_3.5.0-1_all.deb ...
# Unpacking python-configparser (3.5.0-1) ...
# Selecting previously unselected package python-enum34.
# Preparing to unpack .../087-python-enum34_1.1.6-2_all.deb ...
# Unpacking python-enum34 (1.1.6-2) ...
# Selecting previously unselected package python-idna.
# Preparing to unpack .../088-python-idna_2.6-1_all.deb ...
# Unpacking python-idna (2.6-1) ...
# Selecting previously unselected package python-ipaddress.
# Preparing to unpack .../089-python-ipaddress_1.0.17-1_all.deb ...
# Unpacking python-ipaddress (1.0.17-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../090-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-cryptography.
# Preparing to unpack .../091-python-cryptography_2.1.4-1ubuntu1.4_amd64.deb ...
# Unpacking python-cryptography (2.1.4-1ubuntu1.4) ...
# Selecting previously unselected package python-cycler.
# Preparing to unpack .../092-python-cycler_0.10.0-1_all.deb ...
# Unpacking python-cycler (0.10.0-1) ...
# Selecting previously unselected package python-dateutil.
# Preparing to unpack .../093-python-dateutil_2.6.1-1_all.deb ...
# Unpacking python-dateutil (2.6.1-1) ...
# Selecting previously unselected package python-egenix-mxtools.
# Preparing to unpack .../094-python-egenix-mxtools_3.2.9-1_amd64.deb ...
# Unpacking python-egenix-mxtools (3.2.9-1) ...
# Selecting previously unselected package python-egenix-mxdatetime.
# Preparing to unpack .../095-python-egenix-mxdatetime_3.2.9-1_amd64.deb ...
# Unpacking python-egenix-mxdatetime (3.2.9-1) ...
# Selecting previously unselected package python-future.
# Preparing to unpack .../096-python-future_0.15.2-4ubuntu2_all.deb ...
# Unpacking python-future (0.15.2-4ubuntu2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../097-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../098-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-httplib2.
# Preparing to unpack .../099-python-httplib2_0.9.2+dfsg-1ubuntu0.3_all.deb ...
# Unpacking python-httplib2 (0.9.2+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package python-markupsafe.
# Preparing to unpack .../100-python-markupsafe_1.0-1build1_amd64.deb ...
# Unpacking python-markupsafe (1.0-1build1) ...
# Selecting previously unselected package python-jinja2.
# Preparing to unpack .../101-python-jinja2_2.10-1ubuntu0.18.04.1_all.deb ...
# Unpacking python-jinja2 (2.10-1ubuntu0.18.04.1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../102-python-lxml_4.2.1-1ubuntu0.6_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.6) ...
# Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../103-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../104-python-matplotlib-data_2.1.1-2ubuntu3_all.deb ...
# Unpacking python-matplotlib-data (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python-pyparsing.
# Preparing to unpack .../105-python-pyparsing_2.2.0+dfsg1-2_all.deb ...
# Unpacking python-pyparsing (2.2.0+dfsg1-2) ...
# Selecting previously unselected package python-tz.
# Preparing to unpack .../106-python-tz_2018.3-2_all.deb ...
# Unpacking python-tz (2018.3-2) ...
# Selecting previously unselected package python-subprocess32.
# Preparing to unpack .../107-python-subprocess32_3.2.7-3_amd64.deb ...
# Unpacking python-subprocess32 (3.2.7-3) ...
# Selecting previously unselected package python-matplotlib.
# Preparing to unpack .../108-python-matplotlib_2.1.1-2ubuntu3_amd64.deb ...
# Unpacking python-matplotlib (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../109-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...

# %%
### Github CLI ###
# !apt-key adv --keyserver keyserver.ubuntu.com --recv-key C99B11DEB97541F0
# !apt-add-repository https://cli.github.com/packages
# !apt update
# !apt install gh

# %%
### Rinstall ###
# !apt-get install gdebi-core
# !wget https://download2.rstudio.org/server/bionic/amd64/rstudio-server-1.3.1093-amd64.deb
# !gdebi -n rstudio-server-1.3.1093-amd64.deb

# %%
### localtunel install ###
# !npm install -g localtunnel

# %%
### web to open add this /auth-sign-in ###
# !lt --port 8787
